# %% [markdown]
# <a href="https://colab.research.google.com/github/imchinmay/Python/blob/main/01_Basics/25_Pandas_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Cleaning

# %% [markdown]
# Load in the data.

# %%
# Install datasets Library (if not already installed)
# !pip install -U datasets

# Importing Libraries
import pandas as pd
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), float64(2), object(12)
# memory usage: 86.2+ MB

# %%
type(df['job_posted_date'][0])
# Out:
# str

# %% [markdown]
# ## Date and Time

# %% [markdown]
# ### Datetime
#
# #### Notes
#
# * `pd.to_datetime()`: Convert argument to datetime.
#
# #### Example
#
# In our DataFrame the `job_posted_date` is actually a string not a datetime format. First let's convert it to datetime format.
#
# We'll also use `info()` to check if the data type changed from a string to a `datetime` format.

# %%
# Convert 'job_posted_date' to datetime without specifying the exact format
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %% [markdown]
# ### Date
#
# #### Notes
#
# * `dt`: accessor that provides a way to access specialized methods and properties we use to work with datatime data within a pandas series.
# * `date`: extract the date component from the datetime object in the series.
# * Use together `dt.date` on our series.
#
# #### Example
#
# Now let's turn it from a datetime to a date using `dt.date`.

# %%
df['job_posted_day_of_week'] =  df.job_posted_date.dt.day_of_week

# %%
df['job_posted_date'] = df['job_posted_date'].dt.date

df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location job_posted_date  \
# 0               False  Texas, United States      2023-06-16
# 1               False                Mexico      2023-01-14
# 2               False               Germany      2023-10-10
# 3               False  Texas, United States      2023-07-04
# 4               False                 Sudan      2023-08-07
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills  job_posted_day_of_week
# 0                                               None                       4
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...                       5
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...                       1
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...                       1
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...                       0

# %% [markdown]
# #### Note: For the rest of the time we're loading the data in we'll be automatically turn the `job_posted_date` column into a datetime object.

# %% [markdown]
# ## Sorting Values
#
# ### Notes
#
# * `sort_values()` sorts a DataFrame or a specific column in ascending or descending order based on one or more columns.
# * Typically this is used to sort by a specific column/s.
# * Parameters:
#     * `by` - column name or list of column names to sort by
#     * `ascending` - boolean or list of booleans, default `True`, to sort by descending you would use `False`
#     * `inplace` - whether to modify the DataFrame in place or return a new one
#
# ### Example
#
# Let's sort our DataFrame by the `job_posted_date` in descending order (from most recent date to least).

# %%
df.sort_values(by='job_posted_day_of_week', ascending=False,inplace=True)
df
# Out:
#              job_title_short  \
# 298458        Data Scientist
# 298488          Data Analyst
# 785653     Software Engineer
# 785666          Data Analyst
# 38              Data Analyst
# ...                      ...
# 677658      Business Analyst
# 65392           Data Analyst
# 785712         Data Engineer
# 785711  Senior Data Engineer
# 785710  Senior Data Engineer
#
#                                                 job_title  \
# 298458               Senior Staff Engineer Data Scientist
# 298488                                Data Analyst Intern
# 785653                                  Tableau Developer
# 785666          Finance Data Analyst S3 Cfo Milton Keynes
# 38                  Data Quality and Governance Analyst 1
# ...                                                   ...
# 677658     Senior Business Intelligence Analyst - Tableau
# 65392   Corporate Applications Records and Information...
# 785712                     India - Collections Analyst II
# 785711                       Senior Data Engineer (m/w/d)
# 785710  (Senior) Data Engineer (m/w/d) - PUBLIC BW / C...
#
#                                              job_location  \
# 298458                                  Malacca, Malaysia
# 298488                                            Denmark
# 785653  Kuala Lumpur, Federal Territory of Kuala Lumpu...
# 785666                                           Colombia
# 38                                                  India
# ...                                                   ...
# 677658                                     Warsaw, Poland
# 65392                                  Ponce, Puerto Rico
# 785712                                              India
# 785711                                 Düsseldorf, Jerman
# 785710                    Leinfelden-Echterdingen, Jerman
#
#                                               job_via job_schedule_type  \
# 298458                             via BeBee Malaysia         Full-time
# 298488                                      via BeBee        Internship
# 785653                                via Trabajo.org         Full-time
# 785666  via Trabajo.org - Vacantes De Empleo, Trabajo         Full-time
# 38                                    via Trabajo.org         Full-time
# ...                                               ...               ...
# 677658                                   via Linkedin         Full-time
# 65392                                  via Talent.com         Full-time
# 785712                            melalui BeBee India   Pekerjaan tetap
# 785711                             melalui Monster.de   Pekerjaan tetap
# 785710                             melalui Monster.de   Pekerjaan tetap
#
#         job_work_from_home search_location job_posted_date  \
# 298458               False        Malaysia      2023-04-09
# 298488               False         Denmark      2023-01-08
# 785653               False        Malaysia      2023-10-29
# 785666               False        Colombia      2023-09-24
# 38                   False           India      2023-07-23
# ...                    ...             ...             ...
# 677658               False          Poland      2023-02-06
# 65392                False     Puerto Rico      2023-09-18
# 785712               False           India      2023-03-13
# 785711               False         Germany      2023-03-13
# 785710               False         Germany      2023-03-13
#
#         job_no_degree_mention  job_health_insurance  job_country salary_rate  \
# 298458                  False                 False     Malaysia        None
# 298488                  False                 False      Denmark        None
# 785653                  False                 False     Malaysia        None
# 785666                   True                 False     Colombia        None
# 38                      False                 False        India        None
# ...                       ...                   ...          ...         ...
# 677658                   True                 False       Poland        None
# 65392                   False                 False  Puerto Rico        None
# 785712                  False                 False        India        None
# 785711                  False                 False      Germany        None
# 785710                  False                 False      Germany        None
#
#         salary_year_avg  salary_hour_avg                  company_name  \
# 298458              NaN              NaN                      infineon
# 298488              NaN              NaN    Aptiv Services Poland S.A.
# 785653              NaN              NaN      SVI TECHNOLOGIES SDN BHD
# 785666              NaN              NaN                     Santander
# 38                  NaN              NaN    Jones Lang LaSalle IP, Inc
# ...                 ...              ...                           ...
# 677658              NaN              NaN                      EcoVadis
# 65392               NaN              NaN              VirtualVocations
# 785712              NaN              NaN  Varite India Private Limited
# 785711              NaN              NaN               CGI Group, Inc.
# 785710              NaN              NaN               CGI Group, Inc.
#
#                                                job_skills  \
# 298458  ['python', 'sql', 'scikit-learn', 'tensorflow'...
# 298488  ['python', 'go', 'matplotlib', 'express', 'jira']
# 785653                                        ['tableau']
# 785666                        ['go', 'sas', 'sas', 'sql']
# 38      ['sql', 'python', 'databricks', 'power bi', 'e...
# ...                                                   ...
# 677658                   ['sql', 'sql server', 'tableau']
# 65392                                                None
# 785712                                  ['excel', 'flow']
# 785711         ['gcp', 'aws', 'azure', 'spark', 'hadoop']
# 785710  ['python', 'sql', 'azure', 'aws', 'hadoop', 's...
#
#                                           job_type_skills  \
# 298458  {'libraries': ['scikit-learn', 'tensorflow', '...
# 298488  {'async': ['jira'], 'libraries': ['matplotlib'...
# 785653                     {'analyst_tools': ['tableau']}
# 785666  {'analyst_tools': ['sas'], 'programming': ['go...
# 38      {'analyst_tools': ['power bi', 'excel', 'word'...
# ...                                                   ...
# 677658  {'analyst_tools': ['tableau'], 'databases': ['...
# 65392                                                None
# 785712    {'analyst_tools': ['excel'], 'other': ['flow']}
# 785711  {'cloud': ['gcp', 'aws', 'azure'], 'libraries'...
# 785710  {'cloud': ['azure', 'aws'], 'libraries': ['had...
#
#         job_posted_day_of_week
# 298458                       6
# 298488                       6
# 785653                       6
# 785666                       6
# 38                           6
# ...                        ...
# 677658                       0
# 65392                        0
# 785712                       0
# 785711                       0
# 785710                       0
#
# [785741 rows x 18 columns]

# %% [markdown]
# ## Adding a Column
#
# ### Notes
#
# - If you want to create a column you'll need to use the `df['column_name']` syntax.
#
# ### Example
#
# Here we are creating a new column called 'Is Data Analyst' and saying if the column `job_title_short` is equal to 'Data Analyst' then then return 1 if not, return 0. It does this by using `astype(int)`.

# %%
df['Is Data Analyst'] = (df.job_title_short == 'Data Analyst').astype(int)

# %% [markdown]
# Let's view this new column we created.

# %%
df['Is Data Analyst']
# Out:
# 298458    0
# 298488    1
# 785653    0
# 785666    1
# 38        1
#          ..
# 677658    0
# 65392     1
# 785712    0
# 785711    0
# 785710    0
# Name: Is Data Analyst, Length: 785741, dtype: int64

# %% [markdown]
# Did this work? Let's look at cases when this column is greater than 0, which means it is equal to 1 (aka it's true). We can use our row filtering we learned in the last section.

# %%
df[df['Is Data Analyst'] > 0]
# Out:
#        job_title_short                                          job_title  \
# 298488    Data Analyst                                Data Analyst Intern
# 785666    Data Analyst          Finance Data Analyst S3 Cfo Milton Keynes
# 38        Data Analyst              Data Quality and Governance Analyst 1
# 785685    Data Analyst                                       Data Analyst
# 298544    Data Analyst                                       Data-Analist
# ...                ...                                                ...
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785691    Data Analyst                     Business Intelligence Engineer
# 677666    Data Analyst                            Operations Data Analyst
# 677662    Data Analyst                                       Data Analyst
# 65392     Data Analyst  Corporate Applications Records and Information...
#
#                              job_location  \
# 298488                            Denmark
# 785666                           Colombia
# 38                                  India
# 785685                   Indianapolis, IN
# 298544            Nieuwegein, Netherlands
# ...                                   ...
# 785715                              India
# 785691         Chennai, Tamil Nadu, India
# 677666  Manila, Metro Manila, Philippines
# 677662                      Sunnyvale, CA
# 65392                  Ponce, Puerto Rico
#
#                                                   job_via job_schedule_type  \
# 298488                                          via BeBee        Internship
# 785666      via Trabajo.org - Vacantes De Empleo, Trabajo         Full-time
# 38                                        via Trabajo.org         Full-time
# 785685                                    via Trabajo.org         Full-time
# 298544                                          via BeBee         Full-time
# ...                                                   ...               ...
# 785715  melalui Jobsleworld - Jobs In India - Job Vaca...   Pekerjaan tetap
# 785691                                       via LinkedIn         Full-time
# 677666                                       via LinkedIn              None
# 677662                                          via BeBee        Contractor
# 65392                                      via Talent.com         Full-time
#
#         job_work_from_home            search_location job_posted_date  \
# 298488               False                    Denmark      2023-01-08
# 785666               False                   Colombia      2023-09-24
# 38                   False                      India      2023-07-23
# 785685               False    Illinois, United States      2023-07-16
# 298544               False                Netherlands      2023-08-06
# ...                    ...                        ...             ...
# 785715               False                      India      2023-03-13
# 785691               False                      India      2023-01-23
# 677666               False                Philippines      2023-07-24
# 677662               False  California, United States      2023-02-06
# 65392                False                Puerto Rico      2023-09-18
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 298488                  False                 False        Denmark
# 785666                   True                 False       Colombia
# 38                      False                 False          India
# 785685                   True                 False  United States
# 298544                   True                 False    Netherlands
# ...                       ...                   ...            ...
# 785715                  False                 False          India
# 785691                  False                 False          India
# 677666                  False                 False    Philippines
# 677662                   True                 False  United States
# 65392                   False                 False    Puerto Rico
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 298488        None              NaN              NaN
# 785666        None              NaN              NaN
# 38            None              NaN              NaN
# 785685        None              NaN              NaN
# 298544        None              NaN              NaN
# ...            ...              ...              ...
# 785715        None              NaN              NaN
# 785691        None              NaN              NaN
# 677666        None              NaN              NaN
# 677662        None              NaN              NaN
# 65392         None              NaN              NaN
#
#                       company_name  \
# 298488  Aptiv Services Poland S.A.
# 785666                   Santander
# 38      Jones Lang LaSalle IP, Inc
# 785685      Aara Technologies, Inc
# 298544         Gemeente Oisterwijk
# ...                            ...
# 785715                        Amul
# 785691      Mobile Programming LLC
# 677666                  SiteMinder
# 677662                     Experis
# 65392             VirtualVocations
#
#                                                job_skills  \
# 298488  ['python', 'go', 'matplotlib', 'express', 'jira']
# 785666                        ['go', 'sas', 'sas', 'sql']
# 38      ['sql', 'python', 'databricks', 'power bi', 'e...
# 785685                                   ['sql', 'excel']
# 298544                                               None
# ...                                                   ...
# 785715                                               None
# 785691  ['sql', 'python', 'shell', 'sql server', 'tabl...
# 677666                                 ['sql', 'tableau']
# 677662                                          ['excel']
# 65392                                                None
#
#                                           job_type_skills  \
# 298488  {'async': ['jira'], 'libraries': ['matplotlib'...
# 785666  {'analyst_tools': ['sas'], 'programming': ['go...
# 38      {'analyst_tools': ['power bi', 'excel', 'word'...
# 785685  {'analyst_tools': ['excel'], 'programming': ['...
# 298544                                               None
# ...                                                   ...
# 785715                                               None
# 785691  {'analyst_tools': ['tableau', 'microstrategy']...
# 677666  {'analyst_tools': ['tableau'], 'programming': ...
# 677662                       {'analyst_tools': ['excel']}
# 65392                                                None
#
#         job_posted_day_of_week  Is Data Analyst
# 298488                       6                1
# 785666                       6                1
# 38                           6                1
# 785685                       6                1
# 298544                       6                1
# ...                        ...              ...
# 785715                       0                1
# 785691                       0                1
# 677666                       0                1
# 677662                       0                1
# 65392                        0                1
#
# [196075 rows x 19 columns]

# %% [markdown]
# ## Dropping Data
#
# ### Notes
#
# * Use `drop()` if you want to drop (delete) either a column or row in your database.
# * The syntax is:
#     * Drop column: `df.drop('column_name, axis = 1)`
#     * Drop row: `df.drop(index_name, axis = 0)`
# * If you wanted to drop multiple rows you would have the syntax:
#     * Drop multiple columns: `df.drop(['column_name1', 'column_name2'], axis=1)`
#     * Drop multiple rows: `df.drop([index_name1, index_name2], axis=0)`
#
# ### Examples
#
# Let's drop the column `'salary_hour_avg'`, this will have an axis of 1 (since we're dropping a column).

# %%
df.drop('salary_hour_avg', axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3598506947.py in <cell line: 0>()
# ----> 1 df.drop('salary_hour_avg', axis = 1, inplace=True)
#       2 help(df.drop)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['salary_hour_avg'] not found in axis"

# %% [markdown]
# Inspecting the columns available now:

# %%
df.info()
help(df.drop)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 298458 to 785710
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   job_title_short         785741 non-null  object
#  1   job_title               785740 non-null  object
#  2   job_location            784696 non-null  object
#  3   job_via                 785733 non-null  object
#  4   job_schedule_type       773074 non-null  object
#  5   job_work_from_home      785741 non-null  bool
#  6   search_location         785741 non-null  object
#  7   job_posted_date         785741 non-null  object
#  8   job_no_degree_mention   785741 non-null  bool
#  9   job_health_insurance    785741 non-null  bool
#  10  job_country             785692 non-null  object
#  11  salary_rate             33067 non-null   object
#  12  salary_year_avg         22003 non-null   float64
#  13  company_name            785723 non-null  object
#  14  job_skills              668704 non-null  object
#  15  job_type_skills         668704 non-null  object
#  16  job_posted_day_of_week  785741 non-null  int32
#  17  Is Data Analyst         785741 non-null  int64
# dtypes: bool(3), float64(1), int32(1), int64(1), object(12)
# memory usage: 95.2+ MB
# Help on method drop in module pandas.core.frame:
#
# drop(labels: 'IndexLabel | None' = None, *, axis: 'Axis' = 0, index: 'IndexLabel | None' = None, columns: 'IndexLabel | None' = None, level: 'Level | None' = None, inplace: 'bool' = False, errors: 'IgnoreRaise' = 'raise') -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by directly specifying index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the :ref:`user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
#     index : single label or list-like
#         Alternative to specifying axis (``labels, axis=0``
#         is equivalent to ``index=labels``).
#     columns : single label or list-like
#         Alternative to specifying axis (``labels, axis=1``
#         is equivalent to ``columns=labels``).
#     level : int or level name, optional
#         For MultiIndex, level from which the labels will be removed.
#     inplace : bool, default False
#         If False, return a copy. Otherwise, do operation
#         in place and return None.
#     errors : {'ignore', 'raise'}, default 'raise'
#         If 'ignore', suppress error and only existing labels are
#         dropped.
#
#     Returns
#     -------
#     DataFrame or None
#         Returns DataFrame or None DataFrame with the specified
#         index or column labels removed or None if inplace=True.
#
#     Raises
#     ------
#     KeyError
#         If any of the labels is not found in the selected axis.
#
#     See Also
#     --------
#     DataFrame.loc : Label-location based indexer for selection by label.
#     DataFrame.dropna : Return DataFrame with labels on given axis omitted
#         where (all or any) data are missing.
#     DataFrame.drop_duplicates : Return DataFrame with duplicate rows
#         removed, optionally only considering certain columns.
#     Series.drop : Return Series with specified index labels removed.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame(np.arange(12).reshape(3, 4),
#     ...                   columns=['A', 'B', 'C', 'D'])
#     >>> df
#        A  B   C   D
#     0  0  1   2   3
#     1  4  5   6   7
#     2  8  9  10  11
#
#     Drop columns
#
#     >>> df.drop(['B', 'C'], axis=1)
#        A   D
#     0  0   3
#     1  4   7
#     2  8  11
#
#     >>> df.drop(columns=['B', 'C'])
#        A   D
#     0  0   3
#     1  4   7
#     2  8  11
#
#     Drop a row by index
#
#     >>> df.drop([0, 1])
#        A  B   C   D
#     2  8  9  10  11
#
#     Drop columns and/or rows of MultiIndex DataFrame
#
#     >>> midx = pd.MultiIndex(levels=[['llama', 'cow', 'falcon'],
#     ...                              ['speed', 'weight', 'length']],
#     ...                      codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2],
#     ...                             [0, 1, 2, 0, 1, 2, 0, 1, 2]])
#     >>> df = pd.DataFrame(index=midx, columns=['big', 'small'],
#     ...                   data=[[45, 30], [200, 100], [1.5, 1], [30, 20],
#     ...                         [250, 150], [1.5, 0.8], [320, 250],
#     ...                         [1, 0.8], [0.3, 0.2]])
#     >>> df
#                     big     small
#     llama   speed   45.0    30.0
#             weight  200.0   100.0
#             length  1.5     1.0
#     cow     speed   30.0    20.0
#             weight  250.0   150.0
#             length  1.5     0.8
#     falcon  speed   320.0   250.0
#             weight  1.0     0.8
#             length  0.3     0.2
#
#     Drop a specific index combination from the MultiIndex
#     DataFrame, i.e., drop the combination ``'falcon'`` and
#     ``'weight'``, which deletes only the corresponding row
#
#     >>> df.drop(index=('falcon', 'weight'))
#                     big     small
#     llama   speed   45.0    30.0
#             weight  200.0   100.0
#             length  1.5     1.0
#     cow     speed   30.0    20.0
#             weight  250.0   150.0
#             length  1.5     0.8
#     falcon  speed   320.0   250.0
#             length  0.3     0.2
#
#     >>> df.drop(index='cow', columns='small')
#                     big
#     llama   speed   45.0
#             weight  200.0
#             length  1.5
#     falcon  speed   320.0
#             weight  1.0
#             length  0.3
#
#     >>> df.drop(index='length', level=1)
#                     big     small
#     llama   speed   45.0    30.0
#             weight  200.0   100.0
#     cow     speed   30.0    20.0
#             weight  250.0   150.0
#     falcon  speed   320.0   250.0
#             weight  1.0     0.8

# %% [markdown]
# This column is now removed!

# %% [markdown]
# ## Remove NA
#
# ### Notes
#
# * To remove rows that contain empty cells use `dropna()`.
# * By default `dropna()` will return a *new* DataFrame, and won't change the original.
#
# ### Example
#
# Let's cleanup our `salary_year_avg` column by removing the `NaN` values in this column.

# %%
df.salary_year_avg.head()
# Out:
# 298458   NaN
# 298488   NaN
# 785653   NaN
# 785666   NaN
# 38       NaN
# Name: salary_year_avg, dtype: float64

# %%
df.dropna(subset=['salary_year_avg'], inplace=True)

# %%
df.salary_year_avg.head()
# Out:
# 299316    160000.0
# 388        89000.0
# 785132     99150.0
# 297529     84000.0
# 297065    147500.0
# Name: salary_year_avg, dtype: float64

# %%
df.salary_year_avg.mean()
# Out:
# 0    90000.0
# Name: salary_year_avg, dtype: float64

# %%
df.salary_year_avg.median()
# Out:
# 115000.0

# %%
df.salary_year_avg.mode()
# Out:
# 0    90000.0
# Name: salary_year_avg, dtype: float64

# %%
df.sort_values(by='salary_year_avg', ascending=True,inplace=True)
df.salary_year_avg.mode()
# Out:
# 0    90000.0
# Name: salary_year_avg, dtype: float64
